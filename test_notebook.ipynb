# %%
from ocr_to_df_funcs import *

# %%
image_clipboard_to_df()
# Out:
#                              ROI Voxels     BA  Talaraich coordinates  \
# 0                Wernicke’s area    200    NaN      —46.2, —32.2, 3.9
# 1                   Broca’s area    NaN    NaN         —42.6, 15.6, 3
# 2    Left inferior frontal gyrus    150     45      —39, 29.28, 14.85
# 3           Left anterior insula    200     13      —32.5, 15.9, 9.14
# 4                  Left premotor    200      6       —41, —4.93, 47.8
# 5                 Left precuneus    130      7     —22.2, —59.6, 41.2
# 6             Left lingual gyrus    350     18           —8, —90, -11
# 7      Left middle frontal gyrus    250      9     —41.93, 10.2, 35.2
# 8                  Left fusiform    180     37     —34.9, —57, —17.87
# 9           Left parahippocampal    200     28  —26.53, —39.13, —15.4
# 10  Homologue of Wernicke’s area    250  22/42     49.08, —28.9, 6.42
# 11         Right anterior insula    200     13    32.07, 23.07, 11.57
# ...

# %%
image_clipboard_to_df(verbose=True)
# Out:
# image shape: (547, 1355, 4)
# num of vertical lines: 5
# num of horizontal lines: 20
#                              ROI Voxels     BA  Talaraich coordinates  \
# 0                Wernicke’s area    200    NaN      —46.2, —32.2, 3.9
# 1                   Broca’s area    NaN    NaN         —42.6, 15.6, 3
# 2    Left inferior frontal gyrus    150     45      —39, 29.28, 14.85
# 3           Left anterior insula    200     13      —32.5, 15.9, 9.14
# 4                  Left premotor    200      6       —41, —4.93, 47.8
# 5                 Left precuneus    130      7     —22.2, —59.6, 41.2
# 6             Left lingual gyrus    350     18           —8, —90, -11
# 7      Left middle frontal gyrus    250      9     —41.93, 10.2, 35.2
# 8                  Left fusiform    180     37     —34.9, —57, —17.87
# 9           Left parahippocampal    200     28  —26.53, —39.13, —15.4
# 10  Homologue of Wernicke’s area    250  22/42     49.08, —28.9, 6.42
# ...
